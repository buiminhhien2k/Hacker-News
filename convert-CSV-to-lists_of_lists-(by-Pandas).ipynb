# %%
import pandas as pd
hn_panda=pd.read_csv("HN_posts_year_to_Sep_26_2016.csv",header=None)
header=hn_panda.iloc[0]
hn_header=list(header)
# Out:
# C:\Users\ASUS\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (0,3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
hn_panda=hn_panda[1:]
hn_panda=hn_panda.rename(columns=header)

# %%
hn_panda=hn_panda.astype(str)# converting Data Frame into 'object', so that the filter below run smoothly without any omission
hn_panda=hn_panda.loc[hn_panda['num_comments']!='0']
size=hn_panda.shape
hn_panda.index=range(size[0]) #remaking a new row-index for Date Frame base on the shape of the Data Frame
hn=[]
for i in range(0,size[0]):
    i=list(hn_panda.loc[i])
    hn.append(i)

# %%
print(hn_header)
for each_row in hn[0:3]:
    print("\n")
    print(each_row)
print("\n",len(hn))
# Out:
# ['id', 'title', 'url', 'num_points', 'num_comments', 'author', 'created_at']
#
#
# ['12578975', 'Saving the Hassle of Shopping', 'https://blog.menswr.com/2016/09/07/whats-new-with-your-style-feed/', '1', '1', 'bdoux', '9/26/2016 3:13']
#
#
# ['12578908', 'Ask HN: What TLD do you use for local development?', 'nan', '4', '7', 'Sevrene', '9/26/2016 2:53']
#
#
# ['12578822', 'Amazons Algorithms Dont Find You the Best Deals', 'https://www.technologyreview.com/s/602442/amazons-algorithms-dont-find-you-the-best-deals/', '1', '1', 'yarapavan', '9/26/2016 2:26']
#
#  80401

# %%
hn_panda
# Out:
#              id                                              title  \
# 0      12578975                      Saving the Hassle of Shopping
# 1      12578908  Ask HN: What TLD do you use for local developm...
# 2      12578822    Amazons Algorithms Dont Find You the Best Deals
# 3      12578694  Emergency dose of epinephrine that does not co...
# 4      12578624  Phone Makers Could Cut Off Drivers. So Why Don...
# ...         ...                                                ...
# 80396  10176976                                        My Keyboard
# 80397  10176974  Google's new logo was created by Russian desig...
# 80398  10176923  Why we aren't tempted to use ACLs on our Unix ...
# 80399  10176919        Ask HN: What is/are your favorite quote(s)?
# 80400  10176908                  Dying vets fuck you letter (2013)
#
#                                                      url num_points  \
# 0      https://blog.menswr.com/2016/09/07/whats-new-w...          1
# ...

# %%
hn_panda.loc[hn_panda['created_at']=='9/6/2015 5:56']
# Out:
#              id                              title  \
# 80400  10176908  Dying vets fuck you letter (2013)
#
#                                                      url num_points  \
# 80400  http://dangerousminds.net/comments/dying_vets_...         10
#
#       num_comments        author     created_at
# 80400            2  mycodebreaks  9/6/2015 5:56
